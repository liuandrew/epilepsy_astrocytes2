# %%
'''
Import necessary packages
'''
import numpy as np
import scipy
import scipy.integrate
import scipy.signal
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib
from matplotlib import rc
import pickle
from tqdm import tqdm

# from ip3_ca_ode import *
from ip3_ca_ode_cfg import *
import cfg
import os

save = 'figures/paper_plots/'

#set figure font sizes for readability
font = {'size' : 30,
       'family': 'serif',
       'sans-serif': ['Helvetica']}
matplotlib.rc('font', **font)
matplotlib.rc('text', usetex=True)
color_cycle = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', 
               '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # Show the types of experiments that this was tested on

# %%
delays = [120, 240, 600]
cfg.input_max = 0.1
cfg.input_start = 5
cfg.oscillation_on_duration = 30
cfg.num_oscillations = 2
fig, ax = plt.subplots(5, 3, figsize=(12, 8), sharey='row')

cfg.kd2 = 1.2
cfg.v_delta = 0.005
for i, delay in enumerate(delays):
    cfg.oscillation_off_duration = delay
    run_experiment(input_type='oscillation', t_f=1000, max_step=0.5)
    plot_experiment_plots(['glut', 'Gstar', 'lamb', 'Gd1', 'Gd2'], axs=ax[:, i], 
                         add_ylabels=(i==0), add_xlabel=(i==0), ylabel_padding=[-1.2, 0.5])
# plt.tight_layout()

# %%
delays = [120, 240, 600]
cfg.input_max = 0.1
cfg.oscillation_on_duration = 30
cfg.num_oscillations = 2
fig, ax = plt.subplots(5, 3, figsize=(12, 8), sharey='row')

cfg.kd2 = 0.6

for i, delay in enumerate(delays):
    cfg.oscillation_off_duration = delay
    run_experiment(input_type='oscillation', t_f=1000, max_step=0.5)
    plot_experiment_plots(['glut', 'Gstar', 'lamb', 'Gd1', 'Gd2'], axs=ax[:, i], 
                         add_ylabels=(i==0), add_xlabel=(i==0), ylabel_padding=[-1.2, 0.5])
# plt.tight_layout()

# %%
delays = [120, 240, 600]
cfg.input_max = 0.05
cfg.oscillation_on_duration = 180
cfg.num_oscillations = 2
fig, ax = plt.subplots(6, 3, figsize=(12, 8), sharey='row')

cfg.kd2 = 1.2
cfg.v_delta = 0.005
set_init('default')

for i, delay in enumerate(delays):
    cfg.oscillation_off_duration = delay
    run_experiment(input_type='oscillation', t_f=1000, max_step=0.5)
    plot_experiment_plots(['glut', 'Gstar', 'lamb', 'Gd1', 'Gd2', 'c'], axs=ax[:, i], 
                         add_ylabels=(i==0), add_xlabel=(i==0), ylabel_padding=[-1.2, 0.5])
# plt.tight_layout()

# %%
data = pickle.load(open('data/gpcr/glut_classification', 'rb'))

# %%
data
# Out:
#         A  d_decay  d_rise   r_decay  r_rise  response_type  \
# 0    0.05       15       1  0.153506   0.002  O (too small)
# 1    0.05       56       1  0.041118   0.002  O (too small)
# 2    0.05       97       1  0.023738   0.002  O (too small)
# 3    0.05      138       1  0.016685   0.002             SP
# 4    0.05      179       1  0.012864   0.002             SP
# ..    ...      ...     ...       ...     ...            ...
# 595  0.40       56      41  0.078250   0.800             LL
# 596  0.40       97      41  0.045176   0.800             LL
# 597  0.40      138      41  0.031754   0.800             LL
# 598  0.40      179      41  0.024481   0.800             LL
# 599  0.40      220      41  0.019918   0.800             LL
#
#      response_duration    c_total  \
# 0            24.445562   2.380952
# 1            39.264942   4.301892
# 2            33.500000   6.539921
# 3            27.000000   6.761110
# 4            26.000000   6.839808
# ...
